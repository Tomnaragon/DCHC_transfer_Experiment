# %%
import numpy as np

import pandas as pd

#import altair as alt


import bokeh
import bokeh.plotting
from bokeh.plotting import ColumnDataSource
from bokeh.models import LabelSet
import bokeh.io
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_excel('190730_Deuterium_Transfer_Peak_Areas.xlsx')
df2 = pd.read_excel('190730_Deuterium_Transfer_Peak_Areas.xlsx')

# %%
df.tail()
# Out:
#     Species  WellNumber  Peak ID  Ret Time  Start Tm  End Tm  m/z     Area  \
# 115       L          20   D50C24     9.506     9.485   9.530  TIC  2763362
# 116       L          20   D62C30    12.369    12.325  12.425  TIC  1587954
# 117       D          20  Nonanal     4.738     4.715   4.760  TIC  3706443
# 118       D          20   D50C24     9.508     9.490   9.530  TIC    68245
# 119       D          20   D62C30    12.355    12.350  12.420  TIC    15754
#
#      Area Percent   Height  Height Percent   A/H
# 115         34.04  2636982           38.22  1.05
# 116         19.56   691987           10.03  2.29
# 117         97.78  3504817           97.97  1.06
# 118          1.80    64041            1.79  1.07
# 119          0.42     8586            0.24  1.83

# %%
nonanalAreas = np.repeat(df['Area'].loc[df['Peak ID'] == 'Nonanal'],3).reset_index().drop("index", axis=1)
df['Normalized Area'] = np.divide(df['Area'],nonanalAreas['Area'])
df.head()
# Out:
#   Species  WellNumber  Peak ID  Ret Time  Start Tm  End Tm  m/z     Area  \
# 0       L           1  Nonanal     4.741     4.690   4.775  TIC  8160912
# 1       L           1   D50C24     9.513     9.480   9.555  TIC  1916533
# 2       L           1   D62C30    12.382    12.325  12.450  TIC  1044390
# 3       S           1  Nonanal     4.741     4.720   4.765  TIC  7681145
# 4       S           1   D50C24     9.513     9.490   9.535  TIC   150151
#
#    Area Percent   Height  Height Percent   A/H  Normalized Area
# 0         18.59  7096116           25.50  1.15         1.000000
# 1          4.37  1712595            6.15  1.12         0.234843
# 2          2.38   440176            1.58  2.37         0.127975
# 3         97.66  6678748           97.73  1.15         1.000000
# 4          1.91   139963            2.05  1.07         0.019548

# %%
df_plotting = df.loc[df['Peak ID'] != 'Nonanal']

alt.Chart(df_plotting
    ).mark_point(
    ).encode(
        x='Species:N',
        y=alt.Y('Normalized Area',
                type='quantitative',
                scale=alt.Scale(type='log')),
        color='Peak ID:N')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5227ee2e7aae> in <module>
#       1 df_plotting = df.loc[df['Peak ID'] != 'Nonanal']
#       2
# ----> 3 alt.Chart(df_plotting
#       4     ).mark_point(
#       5     ).encode(
#
# NameError: name 'alt' is not defined

# %%
df_C24 = df.loc[df['Peak ID'] == 'D50C24']

p = bokeh.plotting.figure(plot_width=1200,
                          plot_height=600,
                          title='C24',
                          x_axis_label='Species',
                          y_axis_label='D50C24/nonanal',
                          y_axis_type='log')


for i in range(20):
    curSample = df_C24.loc[df_C24['WellNumber'] == i+1]
    if (any(curSample['Species'] == 'S')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curSceptobius=curSample['Normalized Area'].loc[curSample['Species']=='S']
        
        p.circle(1,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(2,curSceptobius,color='Red',legend='Sceptobius',line_width=4)
        p.line([1,2],[curLiometopum,curSceptobius],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[1],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
    if (any(curSample['Species'] == 'P')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curPlatyusa=curSample['Normalized Area'].loc[curSample['Species']=='P']
        
        p.circle(3,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(4,curPlatyusa,color='Green',legend='Platyusa',line_width=4)
        p.line([3,4],[curLiometopum,curPlatyusa],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[3],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
    if (any(curSample['Species'] == 'D')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curDalotia=curSample['Normalized Area'].loc[curSample['Species']=='D']
        
        p.circle(5,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(6,curDalotia,color='Purple',legend='Dalotia',line_width=4)
        p.line([5,6],[curLiometopum,curDalotia],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[5],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
    if (any(curSample['Species'] == 'A')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curAnchoma=curSample['Normalized Area'].loc[curSample['Species']=='A']
        
        p.circle(7,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(8,curAnchoma,color='Orange',legend='Anchoma',line_width=4)
        p.line([7,8],[curLiometopum,curAnchoma],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[7],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
    if (any(curSample['Species'] == 'Blank')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curBlank=curSample['Normalized Area'].loc[curSample['Species']=='Blank']
        
        p.circle(9,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(10,curBlank,color='Cyan',legend='Blank',line_width=4)
        p.line([9,10],[curLiometopum,curBlank],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[9],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
p.xaxis.visible = False
p.xgrid.visible = False
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="6f669195-5de6-4461-8f37-e4e35f4e094b" data-root-id="1004"></div>

# %%
df_C30 = df.loc[df['Peak ID'] == 'D62C30']

p = bokeh.plotting.figure(plot_width=1200,
                          plot_height=600,
                          title='C30',
                          x_axis_label='Species',
                          y_axis_label='D50C24/nonanal',
                          y_axis_type='log')


for i in range(20):
    curSample = df_C30.loc[df_C30['WellNumber'] == i+1]
    if (any(curSample['Species'] == 'S')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curSceptobius=curSample['Normalized Area'].loc[curSample['Species']=='S']
        
        p.circle(1,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(2,curSceptobius,color='Red',legend='Sceptobius',line_width=4)
        p.line([1,2],[curLiometopum,curSceptobius],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[1],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
    if (any(curSample['Species'] == 'P')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curPlatyusa=curSample['Normalized Area'].loc[curSample['Species']=='P']
        
        p.circle(3,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(4,curPlatyusa,color='Green',legend='Platyusa',line_width=4)
        p.line([3,4],[curLiometopum,curPlatyusa],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[3],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
    if (any(curSample['Species'] == 'D')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curDalotia=curSample['Normalized Area'].loc[curSample['Species']=='D']
        
        p.circle(5,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(6,curDalotia,color='Purple',legend='Dalotia',line_width=4)
        p.line([5,6],[curLiometopum,curDalotia],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[5],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
    if (any(curSample['Species'] == 'A')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curAnchoma=curSample['Normalized Area'].loc[curSample['Species']=='A']
        
        p.circle(7,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(8,curAnchoma,color='Orange',legend='Anchoma',line_width=4)
        p.line([7,8],[curLiometopum,curAnchoma],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[7],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
    if (any(curSample['Species'] == 'Blank')):
        curLiometopum=curSample['Normalized Area'].loc[curSample['Species']=='L']
        curBlank=curSample['Normalized Area'].loc[curSample['Species']=='Blank']
        
        p.circle(9,curLiometopum,color='Blue',legend='Liometopum',line_width=4)
        p.circle(10,curBlank,color='Cyan',legend='Blank',line_width=4)
        p.line([9,10],[curLiometopum,curBlank],color='black')
        
        source = ColumnDataSource(
            pd.DataFrame(
                dict(
                    normalized_area=[curLiometopum.values],
                    position=[9],
                    labels=[str(i+1)]
                )
            )
        )
        
        label=bokeh.models.LabelSet(x='position',y='normalized_area',text='labels',level='glyph',
                                   x_offset=-25, y_offset=-10, source=source, render_mode='canvas')
        p.add_layout(label)
        
p.xaxis.visible = False
p.xgrid.visible = False
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="170e99c5-55c1-417f-a78b-b54116fb46d5" data-root-id="5889"></div>

# %%
df_C24 = df.loc[df['Peak ID'] == 'D50C24']

p = bokeh.plotting.figure(plot_width=1200,
                          plot_height=600,
                          title='C24',
                          x_axis_label='Species',
                          y_axis_label='D50C24/nonanal',
                          y_axis_type='log')


for i in range(20):
    curSample = df_C24.loc[df_C24['WellNumber'] == i+1]
    if (any(curSample['Species'] == 'S')):
        plotval=curSample['Normalized Area'].loc[curSample['Species']=='S'].values/curSample['Normalized Area'].loc[curSample['Species']=='L'].values
        
        p.circle(2,plotval,color='Red',legend='Sceptobius',line_width=4)
      
    if (any(curSample['Species'] == 'P')):
        
        plotval=curSample['Normalized Area'].loc[curSample['Species']=='P'].values/curSample['Normalized Area'].loc[curSample['Species']=='L'].values
        
        p.circle(4,plotval,color='Green',legend='Platyusa',line_width=4)
        
      
    if (any(curSample['Species'] == 'D')):
        
        plotval=curSample['Normalized Area'].loc[curSample['Species']=='D'].values/curSample['Normalized Area'].loc[curSample['Species']=='L'].values
        
        p.circle(6,plotval,color='Purple',legend='Dalotia',line_width=4)
        
            
    if (any(curSample['Species'] == 'A')):
        plotval=curSample['Normalized Area'].loc[curSample['Species']=='A'].values/curSample['Normalized Area'].loc[curSample['Species']=='L'].values
        
        p.circle(8,plotval,color='Orange',legend='Anchoma',line_width=4)
      
    if (any(curSample['Species'] == 'Blank')):
        
        plotval=curSample['Normalized Area'].loc[curSample['Species']=='Blank'].values/curSample['Normalized Area'].loc[curSample['Species']=='L'].values
        
        p.circle(10,plotval,color='Cyan',legend='Blank',line_width=4)
               
p.xaxis.visible = False
p.xgrid.visible = False
bokeh.io.show(p)
# Out:
#   <div class="bk-root" id="d8f153e0-7c73-407e-ad4a-1b599a1fe791" data-root-id="12236"></div>

# %%
df_C24
# Out:
#     Species  WellNumber Peak ID  Ret Time  Start Tm  End Tm  m/z     Area  \
# 1         L           1  D50C24     9.513     9.480   9.555  TIC  1916533
# 4         S           1  D50C24     9.513     9.490   9.535  TIC   150151
# 7         L           2  D50C24     9.513     9.490   9.540  TIC  1233745
# 10        A           2  D50C24     9.513     9.495   9.530  TIC    21249
# 13        L           3  D50C24     9.513     9.485   9.540  TIC   892299
# 16    Blank           3  D50C24     9.515     9.490   9.540  TIC     4049
# 19        L           4  D50C24     9.512     9.485   9.535  TIC  4036621
# 22        D           4  D50C24     9.512     9.485   9.535  TIC    18176
# 25        L           5  D50C24     9.512     9.485   9.535  TIC  1412954
# 28        A           5  D50C24     9.511     9.485   9.535  TIC    31091
# 31        L           6  D50C24     9.511     9.485   9.540  TIC   772905
# 34        A           6  D50C24     9.510     9.485   9.540  TIC    13604
# ...

# %%
curSample
# Out:
#     Species  WellNumber Peak ID  Ret Time  Start Tm  End Tm  m/z     Area  \
# 115       L          20  D50C24     9.506     9.485    9.53  TIC  2763362
# 118       D          20  D50C24     9.508     9.490    9.53  TIC    68245
#
#      Area Percent   Height  Height Percent   A/H  Normalized Area
# 115         34.04  2636982           38.22  1.05         0.733421
# 118          1.80    64041            1.79  1.07         0.018413

# %%
curSample['Normalized Area'].loc[curSample['Species']=='D']
# Out:
# 118    0.018413
# Name: Normalized Area, dtype: float64
